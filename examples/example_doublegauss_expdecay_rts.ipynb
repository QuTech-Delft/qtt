# %% [markdown]
# # Analyse RTS

# %% [markdown]
# Loading packages:

# %%
# %matplotlib inline
import numpy as np
from qtt.algorithms.random_telegraph_signal import tunnelrates_RTS

# %% [markdown]
# Generating example data that looks more or less like RTS: a two level system with gaussian noise

# %%
data = np.zeros( (5*100000,))
for i in range(1, data.size):
    if np.random.rand()>.98:
        data[i]=1-data[i-1]
    else:
        data[i]=data[i-1]
data=data+np.random.rand( data.size, )/5
noise = np.random.normal(0,0.1,data.size)
rtsdata = data + noise

# %% [markdown]
# This function takes an RTS dataset, fits a double gaussian, finds the split between the two levels, determines the durations in these two levels, fits a decaying exponantial on two arrays of durations, which gives the tunneling frequency for both the levels.

# %%
example = tunnelrates_RTS(rtsdata, samplerate = 1e6, plungers = [], fig = 1, verbose=1)
# Out:
# addPPTslide: presentation name: quantum-engineers-knowhow.pptx, adding slide 16
# c:\svn\qtt\qtt\tools.py:808: UserWarning: please set notes for the powerpoint slide. e.g. use the station or reshape_metadata
#   'please set notes for the powerpoint slide. e.g. use the station or reshape_metadata')
# Fit paramaters double gaussian:
#  mean down: 0.100 counts, mean up:1.100 counts, std down: 0.116 counts, std up:0.117 counts
# Separation between peaks gaussians: 4.289 std
# Split between two levels: 0.599
# addPPTslide: presentation name: quantum-engineers-knowhow.pptx, adding slide 17
# Tunnel rate down: 19.5 kHz
# addPPTslide: presentation name: quantum-engineers-knowhow.pptx, adding slide 18
# Tunnel rate up: 20.2 kHz
# addPPTslide: presentation name: quantum-engineers-knowhow.pptx, adding slide 19
